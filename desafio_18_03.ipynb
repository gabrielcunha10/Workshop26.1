# %% [markdown]
# ![Screenshot_29.png](data:image/png;base64,...)

# %%
import numpy as np

temperaturas = np.random.uniform(20, 35, 7)

dias_semana = [
    "Segunda",
    "Terça",
    "Quarta",
    "Quinta",
    "Sexta",
    "Sábado",
    "Domingo"
]

# %% [markdown]
# ![Screenshot_30.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd

temperaturas = np.random.uniform(20, 35, 7)

dias_semana = [
    "Segunda",
    "Terça",
    "Quarta",
    "Quinta",
    "Sexta",
    "Sábado",
    "Domingo"
]

df = pd.DataFrame({
    "Dia da semana": dias_semana,
    "Temperatura": temperaturas
})

media_df = df['Temperatura'].mean()
max_df = df['Temperatura'].max()
min_df = df['Temperatura'].min()
print(f"Média das temperaturas da semana: {media_df:.2f}\n", f"Temperatura máxima da semana: {max_df:.2f}\n", f"Temperatura mínima da semana: {min_df:.2f}")
# Out:
# Média das temperaturas da semana: 26.45
#  Temperatura máxima da semana: 34.52
#  Temperatura mínima da semana: 20.08

# %% [markdown]
# ![Screenshot_31.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

temperaturas = np.random.uniform(20, 35, 7)

dias_semana = [
    "Segunda",
    "Terça",
    "Quarta",
    "Quinta",
    "Sexta",
    "Sábado",
    "Domingo"
]

df = pd.DataFrame({
    "Dia da semana": dias_semana,
    "Temperatura": temperaturas
})

x = df["Dia da semana"]
y = df["Temperatura"]

# Primeiro gráfico

plt.bar(x, y, label="Temperatura")
plt.xlabel("Dia da semana")
plt.ylabel("Temperatura")
plt.title("Temperatura média por dia da semana")
plt.grid()
plt.legend()
plt.show()

# Segundo gráfico

plt.plot(x, y, label="Temperatura")
plt.xlabel("Dia da semana")
plt.ylabel("Temperatura")
plt.title("Temperatura média por dia da semana")
plt.grid()
plt.legend()
plt.show()

# Terceiro gráfico

plt.scatter(x, y, label="Temperatura")
plt.xlabel("Dia da semana")
plt.ylabel("Temperatura")
plt.title("Temperatura média por dia da semana")
plt.grid()
plt.legend()
plt.show()
